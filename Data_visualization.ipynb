# %%
# load a library
import pandas as pd
import matplotlib.pyplot as plt
import numpy
import seaborn as sns

# %%
#load a google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/MyDrive/ZummitAfrica(AI ML Learning Path)/Social_Network_Ads.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
x= data.loc[:,['Age']]
x
# Out:
#      Age
# 0     19
# 1     35
# 2     26
# 3     27
# 4     19
# ..   ...
# 395   46
# 396   51
# 397   50
# 398   36
# 399   49
#
# [400 rows x 1 columns]

# %%
y=data.loc[:,['EstimatedSalary']]
y
# Out:
#      EstimatedSalary
# 0              19000
# 1              20000
# 2              43000
# 3              57000
# 4              76000
# ..               ...
# 395            41000
# 396            23000
# 397            20000
# 398            33000
# 399            36000
#
# [400 rows x 1 columns]

# %%
# Scatter plot
plt.scatter(data['Age'], data['EstimatedSalary'])
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.title('Age vs Estimated Salary')
plt.show()

# %%
# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Age', y='EstimatedSalary', data=data)
plt.xlabel('Age')
plt.ylabel('Estimated Salary')
plt.title('Age vs Estimated Salary')
plt.show()

# %%
# Histogram for EstimatedSalary
plt.hist(data['EstimatedSalary'], bins=20)
plt.xlabel('Estimated Salary')
plt.ylabel('Frequency')
plt.title('Estimated Salary Distribution')
plt.show()

# %%
# Pie chart
# Calculate counts for different age groups
age_counts = data['Age'].value_counts()

# Creating plot
fig = plt.figure(figsize=(6, 6))
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart: Age Distribution')

# Show plot
plt.show()
